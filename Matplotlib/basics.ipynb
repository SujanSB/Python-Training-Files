# %% [markdown]
# # Matplotlib: A Fundamental Data Visualization Library
#
# Matplotlib is the foundational plotting library for Python, offering a comprehensive set of tools for creating static, animated, and interactive visualizations.
#
# ## Key Features
# - Publication-quality figures in various formats (PNG, PDF, SVG, etc.)
# - Fine-grained control over plot elements
# - Works seamlessly with NumPy and Pandas
# - Supports diverse plot types: line plots, scatter plots, histograms, bar charts, etc.
#
# ## Common Use Cases in Data Science
# - Exploring data distributions and patterns
# - Visualizing trends and relationships
# - Creating statistical plots
# - Building complex data dashboards
# - Time series analysis visualization
# - Model performance evaluation plots
#
# ## Example
# The code in this notebook demonstrates a basic sine wave plot using Matplotlib, showcasing:
# - Figure size customization
# - Line plotting with color specification
# - Title and axis labels
# - Grid and legend implementation

# %%
import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', label='sin(x)')
plt.title('Basic Matplotlib Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.legend()
plt.show()

# %%
x = [0, 1, 2, 3, 4]
y = [3, 2, 6, 8, 10]

# Set figure size and resolution
plt.figure(figsize=(6, 4), dpi=80)

# Plot first line with points and solid line
plt.plot(x, y, 'r.-', label="2x")

# Create more precise x values using numpy
x2 = np.arange(0, 4.5, 0.5)

# Plot x^3 function in two parts with different styles
plt.plot(x2[4:], x2[4:]**3, 'b*--', label='x^3')  # Dashed line with stars
plt.plot(x2[0:5], x2[0:5]**3, 'g.-', label='x^3')  # Solid line with points

# Set title with a standard font
plt.title("My first graph!", fontsize=20)
plt.rcParams["font.family"] = "monospace"
plt.rcParams["font.monospace"] = ["FreeMono"]

# Set axis labels
plt.xlabel("x axis")
plt.ylabel("y axis")

# Set x-axis ticks
plt.xticks([0, 1, 2, 3, 4])

# Add legend
plt.legend()

# Save figure with high resolution
plt.savefig('mygraph.png', dpi=200)

# Display the plot
plt.show()

# %%
labels =['A','B','C']
values =[1,4,3]
plt.title("My first Bar Charts!",fontdict={"fontsize":20})

bars=plt.bar(labels,values,)
plt.figure(figsize=(6,4))
# bars[0].set_hatch('+')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')

# using loop instead of above code
patterns= ['+','o','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('mycharts.png',dpi=300)

    
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/home/fm-pc-lt-275/Documents/zPERSONAL-OUTSIDE OFFICE/Machine-learning-Teaching/PythonTraining/Numpy_and_Pandas/people_data.csv')

# %%
# Plot: Age distribution histogram
plt.figure(figsize=(15, 10))

plt.hist(df['age'], bins=10, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Left subplot: Salary Distribution by City
df.boxplot(column='salary_num', by='city', ax=ax1)
ax1.set_title('Salary Distribution by City')
ax1.set_ylabel('Salary (k)')
ax1.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
# Convert salary strings to numeric values
salary_numeric = df['salary'].str.replace('k', '').astype(float)

plt.figure(figsize=(10, 6))
plt.scatter(df['age'], salary_numeric, color='blue', alpha=0.6)
plt.plot(df['age'], salary_numeric, linestyle='-', color='red', alpha=0.3)
plt.title('Age vs Salary Trend')
plt.xlabel('Age')
plt.ylabel('Salary (k)')
plt.grid(True, alpha=0.3)
plt.show()

# %%
city_count = df['city'].value_counts()
plt.pie(city_count.values, labels=city_count.index, autopct='%1.1f%%')
plt.title('Employee Distribution by City')

plt.show()

# %%
import pandas as pd
# Create the data as a list of lists
data = [
    [1990, None, 1.87, 3.63, 2.65, 4.59, 3.16, 1, 2.05, 2.82, 1.16],
    [1991, 1.96, 1.92, 3.45, 2.9, 4.5, 3.46, 1.3, 2.49, 3.01, 1.14],
    [1992, 1.89, 1.73, 3.56, 3.27, 4.53, 3.58, 1.5, 2.65, 3.06, 1.13],
    [1993, 1.73, 1.57, 3.41, 3.07, 3.68, 4.16, 1.56, 2.88, 2.84, 1.11],
    [1994, 1.84, 1.45, 3.59, 3.52, 3.7, 4.36, 1.48, 2.87, 2.99, 1.11],
    [1995, 1.95, 1.53, 4.26, 3.96, 4, 4.43, 1.11, 2.94, 3.21, 1.15],
    [1996, 2.12, 1.61, 4.41, 3.94, 4.39, 3.64, 1.25, 3.18, 3.34, 1.23],
    [1997, 2.05, 1.62, 4, 3.53, 4.07, 3.26, 1.47, 3.34, 3.83, 1.23],
    [1998, 1.63, 1.38, 3.87, 3.34, 3.84, 2.82, 1.49, 3.04, 4.06, 1.06],
    [1999, 1.72, 1.52, 3.85, 3.42, 3.87, 3.27, 1.79, 3.8, 4.29, 1.17],
    [2000, 1.94, 1.86, 3.8, 3.45, 3.77, 3.65, 2.01, 4.18, 4.58, 1.51],
    [2001, 1.71, 1.72, 3.51, 3.4, 3.57, 3.27, 2.2, 3.76, 4.13, 1.46],
    [2002, 1.76, 1.69, 3.62, 3.67, 3.74, 3.15, 2.24, 3.84, 4.16, 1.36],
    [2003, 2.19, 1.99, 4.35, 4.59, 4.53, 3.47, 2.04, 4.11, 4.7, 1.59],
    [2004, 2.72, 2.37, 4.99, 5.24, 5.29, 3.93, 2.03, 4.51, 5.56, 1.88],
    [2005, 3.23, 2.89, 5.46, 5.66, 5.74, 4.28, 2.22, 5.28, 5.97, 2.3],
    [2006, 3.54, 3.26, 5.88, 6.03, 6.1, 4.47, 2.31, 5.92, 6.36, 2.59],
    [2007, 3.85, 3.59, 6.6, 6.88, 6.73, 4.49, 2.4, 6.21, 7.13, 2.8],
    [2008, 4.45, 4.08, 7.51, 7.75, 7.63, 5.74, 2.45, 5.83, 7.42, 3.27]
]

# Create DataFrame with appropriate column names
columns = ['Year', 'Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan', 'Mexico', 'South Korea', 'UK', 'USA']
df = pd.DataFrame(data, columns=columns)

# %%
plt.figure(figsize=(12, 8))

countries = df.columns[1:]  # All columns except Year
for country in countries:
    plt.plot(df['Year'], df[country], marker='o', label=country)

plt.title('Economic Trends by Country (1990-2008)')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
